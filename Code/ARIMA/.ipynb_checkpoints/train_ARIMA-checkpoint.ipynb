# %%
import config
import os
import random
import utils

import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn import preprocessing

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)

# %%
saltlake_week = pd.read_csv('../saltlake_week.csv')
saltlake_week
# Out:
#       dates  Cases  VMT (Veh-Miles)  News Sentiment  Unemployment Rate  PRCP  \
# 0    201902      0       66181817.1       -0.589684           0.029341  0.07
# 1    201903      0       65217107.0       -0.716851           0.029341  0.85
# 2    201904      0       63764156.8       -0.795640           0.029341  0.62
# 3    201905      0       68255092.9       -0.791056           0.027660  0.07
# 4    201906      0       60363403.4       -0.327101           0.027660  0.60
# ..      ...    ...              ...             ...                ...   ...
# 156  202201  25264       71548116.2        0.131978                NaN  0.39
# 157  202202  31952       71794673.2       -0.095343                NaN  0.00
# 158  202203  23819       72930069.2       -0.170064                NaN  0.06
# 159  202204  11750       76286409.8       -0.520794                NaN  0.02
# 160  202205   6220              NaN       -0.579581                NaN   NaN
#
#      SNOW  SNWD  Percent_Fully_Vaccinated_5&Older  Stay at Home  Mask  \
# 0     0.4   6.4                          0.000000             0     0
# 1     1.0   1.2                          0.000000             0     0
# 2     4.2  13.3                          0.000000             0     0
# 3     0.0   0.0                          0.000000             0     0
# 4     9.8  19.1                          0.000000             0     0
# ..    ...   ...                               ...           ...   ...
# 156   0.0   5.2                          0.712512             0     1
# 157   0.0   0.0                          0.713689             0     1
# 158   0.6   1.0                          0.713810             0     1
# 159   0.3   0.0                          0.713936             0     0
# 160   NaN   NaN                          0.714011             0     0
#
#      School Opening  Health Emergency       TAVG       TMAX       TMIN  \
# 0                 1                 0  32.285714  36.571429  28.571429
# 1                 1                 0  33.428571  39.857143  27.857143
# 2                 1                 0  31.571429  40.285714  24.571429
# 3                 1                 0  36.142857  46.285714  29.714286
# 4                 1                 0  31.285714  37.000000  22.285714
# ..              ...               ...        ...        ...        ...
# 156               1                 0  35.571429  45.285714  28.571429
# 157               1                 0  32.142857  42.428571  25.000000
# 158               1                 0  30.142857  37.857143  23.857143
# 159               1                 0  29.800000  39.000000  22.600000
# 160               1                 0        NaN        NaN        NaN
#
#      Holiday        Day
# 0          0   1/7/2019
# 1          0  1/14/2019
# 2          1  1/21/2019
# 3          0  1/28/2019
# 4          0   2/4/2019
# ..       ...        ...
# 156        0   1/3/2022
# 157        0  1/10/2022
# 158        1  1/17/2022
# 159        0  1/24/2022
# 160        0  1/31/2022
#
# [161 rows x 18 columns]

# %%
from pandas.plotting import autocorrelation_plot

series = saltlake_week['VMT (Veh-Miles)']
autocorrelation_plot(series)
plt.show()

# %%
y = saltlake_week[['Day', 'VMT (Veh-Miles)']].iloc[:156, :]
y.columns = ['Week', 'VMT']
y['Week'] = pd.to_datetime(y['Week'])
y.head()
# Out:
#         Week         VMT
# 0 2019-01-07  66181817.1
# 1 2019-01-14  65217107.0
# 2 2019-01-21  63764156.8
# 3 2019-01-28  68255092.9
# 4 2019-02-04  60363403.4

# %%
y.shape
# Out:
# (156, 2)

# %%
y.dtypes
# Out:
# Week    datetime64[ns]
# VMT            float64
# dtype: object

# %%
y.set_index('Week', inplace=True)
y.head()
# Out:
#                    VMT
# Week
# 2019-01-07  66181817.1
# 2019-01-14  65217107.0
# 2019-01-21  63764156.8
# 2019-01-28  68255092.9
# 2019-02-04  60363403.4

# %%
y.plot()
# Out:
# <AxesSubplot:xlabel='Week'>

# %%
X = saltlake_week[['Day', 'Cases', 'News Sentiment', 'Unemployment Rate', 'PRCP', 'SNWD',
                         'Percent_Fully_Vaccinated_5&Older', 'TAVG',
                         'Stay at Home', 'Mask', 'School Opening', 'Health Emergency', 'Holiday']].iloc[:156, :]
X.columns = ['Week', 'Cases', 'News Sentiment', 'Unemployment Rate', 'PRCP', 'SNWD',
                         'Percent_Fully_Vaccinated_5&Older', 'TAVG',
                         'Stay at Home', 'Mask', 'School Opening', 'Health Emergency', 'Holiday']
X.head()
# Out:
#         Week  Cases  News Sentiment  Unemployment Rate  PRCP  SNWD  \
# 0   1/7/2019      0       -0.589684           0.029341  0.07   6.4
# 1  1/14/2019      0       -0.716851           0.029341  0.85   1.2
# 2  1/21/2019      0       -0.795640           0.029341  0.62  13.3
# 3  1/28/2019      0       -0.791056           0.027660  0.07   0.0
# 4   2/4/2019      0       -0.327101           0.027660  0.60  19.1
#
#    Percent_Fully_Vaccinated_5&Older       TAVG  Stay at Home  Mask  \
# 0                               0.0  32.285714             0     0
# 1                               0.0  33.428571             0     0
# 2                               0.0  31.571429             0     0
# 3                               0.0  36.142857             0     0
# 4                               0.0  31.285714             0     0
#
#    School Opening  Health Emergency  Holiday
# 0               1                 0        0
# 1               1                 0        0
# 2               1                 0        1
# 3               1                 0        0
# 4               1                 0        0

# %%
X['Week'] = pd.to_datetime(X['Week'])
X.dtypes
# Out:
# Week                                datetime64[ns]
# Cases                                        int64
# News Sentiment                             float64
# Unemployment Rate                          float64
# PRCP                                       float64
# SNWD                                       float64
# Percent_Fully_Vaccinated_5&Older           float64
# TAVG                                       float64
# Stay at Home                                 int64
# Mask                                         int64
# School Opening                               int64
# Health Emergency                             int64
# Holiday                                      int64
# dtype: object

# %%
X.set_index('Week', inplace=True)
X.head()
# Out:
#             Cases  News Sentiment  Unemployment Rate  PRCP  SNWD  \
# Week
# 2019-01-07      0       -0.589684           0.029341  0.07   6.4
# 2019-01-14      0       -0.716851           0.029341  0.85   1.2
# 2019-01-21      0       -0.795640           0.029341  0.62  13.3
# 2019-01-28      0       -0.791056           0.027660  0.07   0.0
# 2019-02-04      0       -0.327101           0.027660  0.60  19.1
#
#             Percent_Fully_Vaccinated_5&Older       TAVG  Stay at Home  Mask  \
# Week
# 2019-01-07                               0.0  32.285714             0     0
# 2019-01-14                               0.0  33.428571             0     0
# 2019-01-21                               0.0  31.571429             0     0
# 2019-01-28                               0.0  36.142857             0     0
# 2019-02-04                               0.0  31.285714             0     0
#
#             School Opening  Health Emergency  Holiday
# Week
# 2019-01-07               1                 0        0
# 2019-01-14               1                 0        0
# 2019-01-21               1                 0        1
# 2019-01-28               1                 0        0
# 2019-02-04               1                 0        0

# %%
from pmdarima.arima import ADFTest
adf_test = ADFTest(alpha = 0.05)
adf_test.should_diff(y)
# Out:
# (0.06504345249740989, True)

# %%
from pmdarima.arima import KPSSTest
kpss_test = KPSSTest(alpha = 0.05)
kpss_test.should_diff(y)
# Out:
# (0.017734973124697174, True)

# %%
trainX = X.iloc[:148, :]
trainY = y.iloc[:148, :]
testX = X.iloc[148:, :]
testY = y.iloc[148:, :]
print(trainX.shape)
print(testY.shape)
# Out:
# (148, 12)
# (8, 1)

# %%
trainX.tail()
# Out:
#             Cases  News Sentiment  Unemployment Rate  PRCP  SNWD  \
# Week
# 2021-10-04   3023       -1.283800           0.018205  0.77   0.0
# 2021-10-11   2747       -1.162625           0.018205  0.45   0.0
# 2021-10-18   3232       -1.070546           0.018205  1.03   0.0
# 2021-10-25   3514       -0.332263           0.018205  1.24   0.0
# 2021-11-01   3676       -0.036116           0.024257  0.06   0.0
#
#             Percent_Fully_Vaccinated_5&Older       TAVG  Stay at Home  Mask  \
# Week
# 2021-10-04                          0.656495  59.857143             0     0
# 2021-10-11                          0.659226  45.000000             0     0
# 2021-10-18                          0.661640  50.142857             0     0
# 2021-10-25                          0.664056  51.428571             0     0
# 2021-11-01                          0.669969  51.571429             0     0
#
#             School Opening  Health Emergency  Holiday
# Week
# 2021-10-04               1                 0        0
# 2021-10-11               1                 0        1
# 2021-10-18               1                 0        0
# 2021-10-25               1                 0        0
# 2021-11-01               1                 0        0

# %%
testX.head()
# Out:
#             Cases  News Sentiment  Unemployment Rate  PRCP  SNWD  \
# Week
# 2021-11-08   3823        0.313240           0.024257  0.25   0.0
# 2021-11-15   3695        0.225556           0.024257  0.03   0.0
# 2021-11-22   2705        0.416588           0.024257  0.00   0.0
# 2021-11-29   3722        0.238616           0.024257  0.00   0.0
# 2021-12-06   2923        0.119803           0.017357  0.57   3.6
#
#             Percent_Fully_Vaccinated_5&Older       TAVG  Stay at Home  Mask  \
# Week
# 2021-11-08                          0.683879  47.000000             0     0
# 2021-11-15                          0.692777  42.571429             0     0
# 2021-11-22                          0.696802  36.142857             0     0
# 2021-11-29                          0.700688  40.285714             0     0
# 2021-12-06                          0.704118  35.571429             0     0
#
#             School Opening  Health Emergency  Holiday
# Week
# 2021-11-08               1                 0        1
# 2021-11-15               1                 0        0
# 2021-11-22               1                 0        1
# 2021-11-29               1                 0        0
# 2021-12-06               1                 0        0

# %%
plt.plot(trainY)
plt.plot(testY)

# %%
from pmdarima.arima import auto_arima

# %%
arima_model =  auto_arima(trainY, trainX, start_p=1, d=1, start_q=1, 
                          max_p=10, max_d=5, max_q=5, 
                          start_P=0, D=None, start_Q=0, 
                          max_P=5, max_D=5, max_Q=5, 
                          m=52, seasonal=True, error_action='warn',trace = True,
                          supress_warnings=True,stepwise = True,
                          random_state=seed_value,n_fits = 50)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[52] intercept   : AIC=4834.248, Time=2.18 sec
#  ARIMA(0,1,0)(0,0,0)[52] intercept   : AIC=4831.346, Time=0.30 sec
#  ARIMA(1,1,0)(1,0,0)[52] intercept   : AIC=4826.619, Time=5.13 sec
#  ARIMA(0,1,1)(0,0,1)[52] intercept   : AIC=4827.292, Time=3.20 sec
#  ARIMA(0,1,0)(0,0,0)[52]             : AIC=5414.299, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[52] intercept   : AIC=4832.966, Time=0.32 sec
#  ARIMA(1,1,0)(2,0,0)[52] intercept   : AIC=4827.223, Time=14.48 sec
#  ARIMA(1,1,0)(1,0,1)[52] intercept   : AIC=4827.416, Time=4.88 sec
#  ARIMA(1,1,0)(0,0,1)[52] intercept   : AIC=4827.379, Time=2.65 sec
#  ARIMA(1,1,0)(2,0,1)[52] intercept   : AIC=4829.182, Time=30.19 sec
#  ARIMA(0,1,0)(1,0,0)[52] intercept   : AIC=4825.037, Time=2.61 sec
#  ARIMA(0,1,0)(2,0,0)[52] intercept   : AIC=4825.617, Time=12.92 sec
#  ARIMA(0,1,0)(1,0,1)[52] intercept   : AIC=4825.791, Time=5.28 sec
#  ARIMA(0,1,0)(0,0,1)[52] intercept   : AIC=4825.797, Time=3.92 sec
#  ARIMA(0,1,0)(2,0,1)[52] intercept   : AIC=4827.580, Time=27.93 sec
#  ARIMA(0,1,1)(1,0,0)[52] intercept   : AIC=4826.521, Time=2.95 sec
#  ARIMA(1,1,1)(1,0,0)[52] intercept   : AIC=4827.732, Time=6.37 sec
#  ARIMA(0,1,0)(1,0,0)[52]             : AIC=4824.793, Time=3.17 sec
#  ARIMA(0,1,0)(2,0,0)[52]             : AIC=4886.904, Time=12.86 sec
#  ARIMA(0,1,0)(1,0,1)[52]             : AIC=4823.393, Time=7.22 sec
#  ARIMA(0,1,0)(0,0,1)[52]             : AIC=4823.655, Time=5.04 sec
#  ARIMA(0,1,0)(2,0,1)[52]             : AIC=4825.379, Time=17.29 sec
#  ARIMA(0,1,0)(1,0,2)[52]             : AIC=4825.274, Time=14.70 sec
#  ARIMA(0,1,0)(0,0,2)[52]             : AIC=4823.275, Time=13.86 sec
#  ARIMA(0,1,0)(0,0,3)[52]             : AIC=4825.173, Time=40.50 sec
#  ARIMA(0,1,0)(1,0,3)[52]             : AIC=4827.174, Time=36.40 sec
#  ARIMA(1,1,0)(0,0,2)[52]             : AIC=4825.106, Time=11.19 sec
#  ARIMA(0,1,1)(0,0,2)[52]             : AIC=4825.011, Time=30.97 sec
#  ARIMA(1,1,1)(0,0,2)[52]             : AIC=4826.210, Time=41.01 sec
#  ARIMA(0,1,0)(0,0,2)[52] intercept   : AIC=4825.594, Time=15.23 sec
#
# Best model:  ARIMA(0,1,0)(0,0,2)[52]
# Total fit time: 375.130 seconds

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  148
# Model:             SARIMAX(0, 1, 0)x(0, 0, [1, 2], 52)   Log Likelihood               -2396.638
# Date:                                 Thu, 17 Feb 2022   AIC                           4823.275
# Time:                                         14:05:26   BIC                           4868.132
# Sample:                                              0   HQIC                          4841.501
#                                                  - 148
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           -57.1928    785.786     -0.073      0.942   -1597.305    1482.919
# x2          1.075e+06   1.12e+06      0.962      0.336   -1.12e+06    3.27e+06
# x3         -7.161e+07     87.233  -8.21e+05      0.000   -7.16e+07   -7.16e+07
# x4         -1.737e+06   8.04e+05     -2.161      0.031   -3.31e+06   -1.62e+05
# x5         -2.672e+05   6.92e+04     -3.858      0.000   -4.03e+05   -1.31e+05
# x6          7.857e+06   3248.626   2418.471      0.000    7.85e+06    7.86e+06
# x7          4.065e+04   6.23e+04      0.652      0.514   -8.15e+04    1.63e+05
# x8         -4.041e+06   4598.342   -878.900      0.000   -4.05e+06   -4.03e+06
# x9         -2.594e+06   2.34e+05    -11.070      0.000   -3.05e+06   -2.13e+06
# x10         2.287e+06   1.04e+06      2.198      0.028    2.48e+05    4.33e+06
# x11         1.668e+06   1.98e+04     84.326      0.000    1.63e+06    1.71e+06
# x12        -2.846e+06   4.99e+05     -5.700      0.000   -3.82e+06   -1.87e+06
# ma.S.L52       0.1106      0.073      1.506      0.132      -0.033       0.255
# ma.S.L104      0.0695      0.198      0.351      0.726      -0.319       0.458
# sigma2      9.302e+12      0.567   1.64e+13      0.000     9.3e+12     9.3e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.84   Jarque-Bera (JB):               530.01
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.45   Skew:                            -1.43
# Prob(H) (two-sided):                  0.01   Kurtosis:                        11.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.81e+28. Standard errors may be unstable.
# """

# %%
arima_model.get_params()
# Out:
# {'maxiter': 50,
#  'method': 'lbfgs',
#  'order': (0, 1, 0),
#  'out_of_sample_size': 8,
#  'scoring': 'mse',
#  'scoring_args': {},
#  'seasonal_order': (0, 0, 2, 52),
#  'start_params': None,
#  'suppress_warnings': True,
#  'trend': None,
#  'with_intercept': False}

# %%
arima_model.arima_res_.data.endog.shape
# Out:
# (148,)

# %%
prediction = pd.DataFrame(arima_model.predict(n_periods = 8, X=testX),index=testX.index)
prediction.columns = ['Predicted_VMT']
prediction
# Out:
#             Predicted_VMT
# Week
# 2021-11-08   7.673523e+07
# 2021-11-15   7.938470e+07
# 2021-11-22   7.592921e+07
# 2021-11-29   7.979008e+07
# 2021-12-06   7.808742e+07
# 2021-12-13   7.148864e+07
# 2021-12-20   7.169790e+07
# 2021-12-27   6.908488e+07

# %%
plt.figure(figsize=(8,5))
plt.plot(trainY,label="Training")
plt.plot(testY,label="Test")
plt.plot(prediction,label="Predicted")
plt.legend(loc = 'upper left')
plt.show()

# %%
from sklearn.metrics import r2_score
testY = pd.DataFrame(testY)
testY['Predicted_VMT'] = prediction
testY
# Out:
#                    VMT  Predicted_VMT
# Week
# 2021-11-08  79542545.3   7.673523e+07
# 2021-11-15  80116497.7   7.938470e+07
# 2021-11-22  72167973.1   7.592921e+07
# 2021-11-29  79550158.9   7.979008e+07
# 2021-12-06  75668913.3   7.808742e+07
# 2021-12-13  77809476.1   7.148864e+07
# 2021-12-20  71502911.8   7.169790e+07
# 2021-12-27  62352608.0   6.908488e+07

# %%
r2_score(testY['VMT'], testY['Predicted_VMT'])
# Out:
# 0.5552792901959523

# %%
mean_absolute_percentage_error(testY['VMT'], testY['Predicted_VMT'])
# Out:
# 0.04043198546491701

# %%
mean_squared_error(testY['VMT'], testY['Predicted_VMT'])
# Out:
# 14223095383304.97

# %%
mean_squared_error(testY['VMT'], testY['Predicted_VMT'], squared=False)
# Out:
# 3771351.9304494737
